# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Histogram: Price distribution
df["price"].plot(kind="hist", bins=20, color="skyblue", edgecolor="black")
plt.title("Distribution of Book Prices")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.show()

# %%
# Pie chart: Availability
availability_count = df["availability"].value_counts()
availability_count.plot(kind="pie", autopct="%1.1f%%", startangle=140, colors=["lightgreen", "lightcoral"])
plt.title("Availability of Books")
plt.ylabel("")  # Hide y-label
plt.show()
